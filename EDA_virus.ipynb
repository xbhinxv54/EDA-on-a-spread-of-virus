# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("Train.csv")

# %%
data.info
# Out:
# <bound method DataFrame.info of       ID  Cough  Shortness of breath  Fatigue  body aches  Headache  \
# 0    309      2                    3        2           0       2.0
# 1    486      2                    2        1           0       0.0
# 2    199      3                    3        3           0       2.0
# 3    495      2                    1        3           0       2.0
# 4    401      3                    2        2           0       0.0
# ..   ...    ...                  ...      ...         ...       ...
# 407  355      2                    2        2           0       0.0
# 408  231      3                    2        3           0       2.0
# 409   22      3                    3        2           0       0.0
# 410  192      1                    1        1           0       2.0
# 411  233      2                    2        3           0       0.0
#
#      Loss of taste family history  Loss of smell  Nausea  ...  \
# ...

# %%
data.describe()
# Out:
#                ID       Cough  Shortness of breath     Fatigue  body aches  \
# count  412.000000  412.000000           412.000000  412.000000  412.000000
# mean   290.992718    2.165049             1.941748    1.553398    0.094660
# std    166.180939    0.652110             0.698629    0.898533    0.428056
# min      1.000000    0.000000             0.000000    0.000000    0.000000
# 25%    153.750000    2.000000             2.000000    1.000000    0.000000
# 50%    288.000000    2.000000             2.000000    2.000000    0.000000
# 75%    428.250000    3.000000             2.000000    2.000000    0.000000
# max    587.000000    3.000000             3.000000    3.000000    3.000000
#
#          Headache  Loss of taste  Loss of smell      Nausea    Diarrhea  \
# count  402.000000     412.000000     412.000000  402.000000  411.000000
# mean     0.763682       0.701456       0.783981    0.174129    1.277372
# std      1.064679       1.011225       0.873751    0.639145    1.158615
# ...

# %%
data.columns
# Out:
# Index(['ID', 'Cough', 'Shortness of breath', 'Fatigue', 'body aches',
#        'Headache', 'Loss of taste', 'family history', 'Loss of smell',
#        'Nausea', 'Diarrhea', 'Misc Symptom 1', 'Congestion', 'Sore throat',
#        'Region', 'Misc Symptom 2', 'Misc Symptom 3', 'Misc Symptom 4',
#        'Misc Symptom 5', 'Misc Symptom 6', 'Misc Symptom 7',
#        'Pre-existing symptoms', 'Age', 'Variant'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# ID                         0
# Cough                      0
# Shortness of breath        0
# Fatigue                    0
# body aches                 0
# Headache                  10
# Loss of taste              0
# family history             0
# Loss of smell              0
# Nausea                    10
# Diarrhea                   1
# Misc Symptom 1             1
# Congestion                 0
# Sore throat                0
# Region                     0
# Misc Symptom 2             0
# Misc Symptom 3             0
# Misc Symptom 4             0
# Misc Symptom 5             0
# Misc Symptom 6             0
# Misc Symptom 7             0
# Pre-existing symptoms    404
# Age                        0
# Variant                    0
# dtype: int64

# %%
dn = data.drop(['Pre-existing symptoms',] ,axis=1) #most of the values(404 out of 412) are zero for pre existing symptoms

# %%
dn['Region'].value_counts()
# Out:
# Region
# Europe                238
# Americas               90
# East Mediterranean     57
# Africa                 27
# Name: count, dtype: int64

# %%
##Outliers
#No outlo=iers could be found ,all the given columns have
#maximum value of 3 and minimum value is 0 which is within the given range.
#Age 0 was not removed as babies below the age of 1 can alse be included in the dataset

# %%
import seaborn as sns

# %%
dn.Region.unique()
# Out:
# array(['Americas', 'Europe', 'East Mediterranean', 'Africa'], dtype=object)

# %%
sns.relplot(x='Age',y='Variant',hue='Region',data=dn)

# %%
dn.hist(column='Variant',by='Region')
# Out:
# array([[<Axes: title={'center': 'Africa'}>,
#         <Axes: title={'center': 'Americas'}>],
#        [<Axes: title={'center': 'East Mediterranean'}>,
#         <Axes: title={'center': 'Europe'}>]], dtype=object)

# %%
#We find that Variant 1 can be found in all four regions.Americas and East Mediterranean has only variant 1 while Europe 
#has all the 6 variants

# %%
euro=['Europe']
euro_dn = dn[dn['Region'].isin(euro)]

# %%
euro_dn['Variant'].value_counts()
# Out:
# Variant
# Variant 2    108
# Variant 3     51
# Variant 4     36
# Variant 5     28
# Variant 6     11
# Variant 1      4
# Name: count, dtype: int64

# %%
sns.relplot(x='Age',y='Variant',data=euro_dn)

# %%
#we observe that variant 6 is found in people below the age of 20
#variant 1 is the least common in Europe and variant 2 the most

# %%
euro_dn.hist(column='Age',by='Variant') #each variant vs age in europe
# Out:
# array([[<Axes: title={'center': 'Variant 1'}>,
#         <Axes: title={'center': 'Variant 2'}>],
#        [<Axes: title={'center': 'Variant 3'}>,
#         <Axes: title={'center': 'Variant 4'}>],
#        [<Axes: title={'center': 'Variant 5'}>,
#         <Axes: title={'center': 'Variant 6'}>]], dtype=object)

# %%
eurov2=['Variant 2']
euro_dnv = euro_dn[euro_dn['Variant'].isin(eurov2)]

# %%
euro_dnv.hist(column='Age',bins=15) #variant 2 in europe
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
#we find that variant is most common in between the age group of 20 and 30

# %%
eurov3=['Variant 3']
euro_dnv3 = euro_dn[euro_dn['Variant'].isin(eurov3)]

# %%
euro_dnv3.hist(column='Age',bins=12) #variant 3 in europe is most common among 40 to 50 year olds
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
eurov4=['Variant 4']
euro_dnv4 = euro_dn[euro_dn['Variant'].isin(eurov4)]

# %%
euro_dnv4.hist(column='Age',bins=9)
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
#VARIANT 4 is most common among 20 to 30 year olds and least among 60 to 70 year olds

# %%
v2=['Variant 1']
dnv2 = dn[dn['Variant'].isin(v2)]

# %%
sns.relplot(x='Age',y='Region',data=dnv2)

# %%
dnv2['Region'].value_counts()
# Out:
# Region
# Americas              90
# East Mediterranean    57
# Africa                24
# Europe                 4
# Name: count, dtype: int64

# %%
#Variant1 is most common in Americas

# %%
av1=['Americas']
dn_av1 = dn[dn['Region'].isin(av1)]

# %%
dn_av1.hist(column='Age',bins=15)
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
# variant 1 ismost common among 20 to 30 year olds

# %%
EM=['East Mediterranean']
em_dn = dn[dn['Region'].isin(EM)]  #East mediterranean only

# %%
v2=['Variant 1']
dnv2 = em_dn[em_dn['Variant'].isin(v2)] #Variant 1 in East medetirranean

# %%
dnv2.hist(column='Age')
# Out:
# array([[<Axes: title={'center': 'Age'}>]], dtype=object)

# %%
##CORELATION MATRIX
import matplotlib.pyplot as plt

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True,linewidth=0.5)
#       2 plt.gcf().set_size_inches(15, 8) #no correlation greater than a threshold magnitude (0.85) could be found
#
# NameError: name 'corelation' is not defined

# %%
dn[dn['Nausea'].isna()]
# Out:
#       ID  Cough  Shortness of breath  Fatigue  body aches  Headache  \
# 8     87      2                    2        0           0       0.0
# 128    7      2                    3        0           0       0.0
# 153  404      1                    1        2           0       0.0
# 183  198      2                    1        0           0       0.0
# 210  280      2                    2        1           0       2.0
# 239  163      2                    2        2           0       0.0
# 277  102      3                    2        0           0       0.0
# 320  227      2                    2        1           0       0.0
# 360  406      2                    1        1           0       0.0
# 399  499      2                    2        2           0       1.0
#
#      Loss of taste family history  Loss of smell  Nausea  ...  Sore throat  \
# 8                0            Yes              2     NaN  ...            0
# ...

# %%
dx=dn.infer_objects()

# %%
dx.isnull().sum()
# Out:
# ID                      0
# Cough                   0
# Shortness of breath     0
# Fatigue                 0
# body aches              0
# Headache               10
# Loss of taste           0
# family history          0
# Loss of smell           0
# Nausea                 10
# Diarrhea                1
# Misc Symptom 1          1
# Congestion              0
# Sore throat             0
# Region                  0
# Misc Symptom 2          0
# Misc Symptom 3          0
# Misc Symptom 4          0
# Misc Symptom 5          0
# Misc Symptom 6          0
# Misc Symptom 7          0
# Age                     0
# Variant                 0
# dtype: int64

# %%
#Pre existing symptoms was removed earlier as it contained majority of null values, the dataset was checked for outliers
#All the null values has been interpolated

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
dn['Region'] = le.fit_transform(dn['Region'])
dn['Variant'] = le.fit_transform(dn['Variant'])
dn['family history'] = le.fit_transform(dn['family history'])

# %%
dn['Symptom_Severity'] = dn[['Cough', 'Shortness of breath', 'Fatigue', 'Headache', 'Loss of taste', 'Loss of smell']].sum(axis=1)

# %%
plt.figure(figsize=(12,8))
sns.heatmap(dn.corr(), annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Matrix of All Features")
plt.show()

# %%
sns.countplot(x='Region', hue='Cough', data=dn)
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
# Reset index of X to match dn
X = X.reset_index(drop=True)

# Fit KMeans
kmeans = KMeans(n_clusters=3, random_state=42).fit(X)

# Add cluster labels to the original DataFrame
dn = dn.reset_index(drop=True)  # Reset index of the original DataFrame
dn['Cluster'] = kmeans.labels_[:len(dn)]
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[59], line 9
#       7 # Add cluster labels to the original DataFrame
#       8 dn = dn.reset_index(drop=True)  # Reset index of the original DataFrame
# ----> 9 dn['Cluster'] = kmeans.labels_[:len(dn)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# ...

# %%
# Check for missing values
print(X.isnull().sum())

# Drop rows with missing values
X = X.dropna()

# Verify the number of rows
print(f"Rows after dropping missing values: {X.shape[0]}")
# Out:
# Cough                  0
# Shortness of breath    0
# Fatigue                0
# Headache               0
# Loss of taste          0
# Loss of smell          0
# dtype: int64
# Rows after dropping missing values: 402

# %%
# Reset index of X to match dn
X = X.reset_index(drop=True)

# Fit KMeans
kmeans = KMeans(n_clusters=3, random_state=42).fit(X)

# Add cluster labels to the original DataFrame
dn = dn.reset_index(drop=True)  # Reset index of the original DataFrame
dn['Cluster'] = kmeans.labels_[:len(dn)]
# Out:
# C:\Users\Lenovo\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\cluster\_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[62], line 9
#       7 # Add cluster labels to the original DataFrame
#       8 dn = dn.reset_index(drop=True)  # Reset index of the original DataFrame
# ----> 9 dn['Cluster'] = kmeans.labels_[:len(dn)]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4091, in DataFrame.__setitem__(self, key, value)
#    4088     self._setitem_array([key], value)
#    4089 else:
#    4090     # set column
# -> 4091     self._set_item(key, value)
#
# ...

# %%
# Ensure dn is aligned with X
aligned_dn = dn.loc[X.index].reset_index(drop=True)

# Assign cluster labels
aligned_dn['Cluster'] = kmeans.labels_
